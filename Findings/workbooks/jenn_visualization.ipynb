# %% [markdown]
# # Jenn Allen's Visualizations for WHO Mortality Data
# These visualizations are based on World Health Organization (WHO) mortality data for a set of [12 countries](../source_data/filtered_countries.csv).

# %% [markdown]
# ### Do Imports, Load Data, and Create DataFrames

# %%
# Import dependencies
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import ScalarFormatter
import seaborn as sns

# Get current working directory
current_dir = Path.cwd()
print(f"Current Working Directory: {current_dir}")
# Out:
# Current Working Directory: /Users/jenn/Source/Group-Project-1/Findings/workbooks

# %%
# Create DataFrames from the source data
mortality_data_path = Path('../../Resources/source_data/current_who_mortality_2017_2021.csv')
population_data_path = Path('../../Resources/source_data/current_who_population.csv')

# Load the WHO mortality data
df_mort = pd.read_csv(mortality_data_path)

# Load the WHO population data
df_pop = pd.read_csv(population_data_path)

# %%
# Create a function to display the total deaths in a year, with country optional

def total_deaths(df, year=None, country=""):
    # Step 1: Filter the DataFrame for the specified country if provided
    if country:
        filtered_df = df[df['Country Name'] == country]
    else:
        filtered_df = df

    # Step 2: Filter the DataFrame for the specified year if provided
    if year:
        filtered_df = filtered_df[filtered_df['Year'] == year]

    # Step 3: Filter for ICD Code 'AAA'
    filtered_df = filtered_df[filtered_df['ICD Code'] == 'AAA']

    # Step 4: Sum the number of deaths
    total_deaths = filtered_df['Deaths: All Ages'].sum()

    # Step 5: Return the result
    return total_deaths

# %% [markdown]
# ### Function to Display the Total Deaths (Year and Country are Optional)

# %%
# Sum of all deaths for 2017 - 2021
print(f"Total deaths from 2017 to 2021: {total_deaths(df_mort):,}")

# Sum of deaths for 2017
print(f"Total deaths in 2017: {total_deaths(df_mort, 2017):,}")

# Sum of deaths for 2018
print(f"Total deaths in 2018: {total_deaths(df_mort, 2018):,}")

# Sum of deaths for 2019
print(f"Total deaths in 2019: {total_deaths(df_mort, 2019):,}")

# Sum of deaths for 2020
print(f"Total deaths in 2020: {total_deaths(df_mort, 2020):,}")

# Sum of deaths for 2021
print(f"Total deaths in 2021: {total_deaths(df_mort, 2021):,}")
# Out:
# Total deaths from 2017 to 2021: 35,681,090
# Total deaths in 2017: 6,600,541
# Total deaths in 2018: 6,642,894
# Total deaths in 2019: 6,717,207
# Total deaths in 2020: 7,603,703
# Total deaths in 2021: 8,116,745

# %% [markdown]
# ### Function to Display the Top 10 Causes of Death in a Year (Country is Optional)

# %%
# Create a function to display the top 10 causes of death in a year

def top_causes_death_yearly(df, year, country=""):
    # Step 1: Filter the DataFrame for the specified year and country
    if country:
        filtered_df = df[(df['Year'] == year) & (df['Country Name'] == country)]
    else:
        filtered_df = df[df['Year'] == year]

    # Step 2: Group by ICD codes and sum the number of deaths
    icd_deaths = filtered_df.groupby('ICD Code')['Deaths: All Ages'].sum().reset_index()
    icd_deaths.columns = ['ICD Code', 'Deaths: All Ages']

    # Step 3: Exclude the 'AAA' ICD code since it applies to total deaths from all causes
    icd_deaths = icd_deaths[icd_deaths['ICD Code'] != 'AAA']

    # Step 4: Select the top 10 ICD codes based on the total number of deaths
    top_10_icd_codes = icd_deaths.nlargest(10, 'Deaths: All Ages')

    # Step 5: Merge with the ICD Category column
    top_10_with_category = top_10_icd_codes.merge(filtered_df[['ICD Code', 'ICD Category']].drop_duplicates(), on='ICD Code', how='left')

    # Step 6: Return the result
    return top_10_with_category

# %% [markdown]
# ### Top Causes of Death in 2020 and 2021
# This shows deaths for each year in our dataset (2017 - 2021). Reminder: our dataset is filtered to a set of [12 countries](../source_data/filtered_countries.csv).

# %%
# Top causes of death for 2017
top_causes_2017 = top_causes_death_yearly(df_mort, 2017)
print(f"The top causes of death for 2017:")
display(top_causes_2017)
print("***" * 50)

# Top causes of death for 2018
top_causes_2018 = top_causes_death_yearly(df_mort, 2018)
print(f"The top causes of death for 2018:")
display(top_causes_2018)
print("***" * 50)

# Top causes of death for 2019
top_causes_2019 = top_causes_death_yearly(df_mort, 2019)
print(f"The top causes of death for 2019:")
display(top_causes_2019)
print("***" * 50)

# Top causes of death for 2020
top_causes_2020 = top_causes_death_yearly(df_mort, 2020)
print(f"The top causes of death for 2020:")
display(top_causes_2020)
print("***" * 50)

# Top causes of death for 2021
top_causes_2021 = top_causes_death_yearly(df_mort, 2021)
print(f"The top causes of death for 2021:")
display(top_causes_2021)
# Out:
# The top causes of death for 2017:
#   ICD Code  Deaths: All Ages  \
# 0     C349            281747
# 1     I219            266528
# 2     J189            207943
# 3     I251            198422
# 4     J449            161289
# 5      F03            157420
# 6     G309            157215
# 7      R54            124986
# 8     I509            118914
# 9      I64            115476
#
#                                         ICD Category
# 0                                          Neoplasms
# 1                        Circulatory system diseases
# 2                        Respiratory system diseases
# 3                        Circulatory system diseases
# 4                        Respiratory system diseases
# 5  Mental, behavioral, and neurodevelopmental dis...
# 6                            Nervous system diseases
# 7  Symptoms, signs and abnormal clinical and labo...
# 8                        Circulatory system diseases
# 9                        Circulatory system diseases
# ******************************************************************************************************************************************************
# The top causes of death for 2018:
#   ICD Code  Deaths: All Ages  \
# 0     C349            276659
# 1     I219            259476
# 2     J189            204501
# 3     I251            198285
# 4     J449            160640
# 5      F03            159909
# 6     G309            157344
# 7      R54            137398
# 8     I509            124818
# 9     I500            114542
#
#                                         ICD Category
# 0                                          Neoplasms
# 1                        Circulatory system diseases
# 2                        Respiratory system diseases
# 3                        Circulatory system diseases
# 4                        Respiratory system diseases
# 5  Mental, behavioral, and neurodevelopmental dis...
# 6                            Nervous system diseases
# 7  Symptoms, signs and abnormal clinical and labo...
# 8                        Circulatory system diseases
# 9                        Circulatory system diseases
# ******************************************************************************************************************************************************
# The top causes of death for 2019:
#   ICD Code  Deaths: All Ages  \
# 0     C349            274362
# 1     I219            254373
# 2     J189            203085
# 3     I251            197767
# 4      F03            159748
# 5     J449            159417
# 6     G309            156065
# 7      R54            153695
# 8     I509            130462
# 9     I500            114263
#
#                                         ICD Category
# 0                                          Neoplasms
# 1                        Circulatory system diseases
# 2                        Respiratory system diseases
# 3                        Circulatory system diseases
# 4  Mental, behavioral, and neurodevelopmental dis...
# 5                        Respiratory system diseases
# 6                            Nervous system diseases
# 7  Symptoms, signs and abnormal clinical and labo...
# 8                        Circulatory system diseases
# 9                        Circulatory system diseases
# ******************************************************************************************************************************************************
# The top causes of death for 2020:
#   ICD Code  Deaths: All Ages  \
# 0     U071            624177
# 1     C349            269087
# 2     I219            252688
# 3     I251            208005
# 4     J189            172954
# 5     G309            168186
# 6      F03            164883
# 7      R54            164267
# 8     J449            152925
# 9      R99            132996
#
#                                         ICD Category
# 0                         Codes for special purposes
# 1                                          Neoplasms
# 2                        Circulatory system diseases
# 3                        Circulatory system diseases
# 4                        Respiratory system diseases
# 5                            Nervous system diseases
# 6  Mental, behavioral, and neurodevelopmental dis...
# 7  Symptoms, signs and abnormal clinical and labo...
# 8                        Respiratory system diseases
# 9  Symptoms, signs and abnormal clinical and labo...
# ******************************************************************************************************************************************************
# The top causes of death for 2021:
#   ICD Code  Deaths: All Ages  \
# 0     U071            955850
# 1     C349            269377
# 2     I219            258364
# 3     I251            214475
# 4      R54            173254
# 5     J189            159063
# 6     G309            156431
# 7      F03            154453
# 8     J449            147485
# 9     I509            136727
#
#                                         ICD Category
# 0                         Codes for special purposes
# 1                                          Neoplasms
# 2                        Circulatory system diseases
# 3                        Circulatory system diseases
# 4  Symptoms, signs and abnormal clinical and labo...
# 5                        Respiratory system diseases
# 6                            Nervous system diseases
# 7  Mental, behavioral, and neurodevelopmental dis...
# 8                        Respiratory system diseases
# 9                        Circulatory system diseases

# %% [markdown]
# #### Calculate and plot total deaths by Sex, year-over-year

# %%
# Group by 'Year' and 'Sex' and sum the deaths
df_filter_icd_aaa = df_mort[df_mort['ICD Code'] != 'AAA']
df_grouped = df_filter_icd_aaa.groupby(['Year', 'Sex'])
sum_yearly_deaths_by_sex = df_grouped[['Deaths: All Ages']].sum().reset_index()

# Sort the data by the total number of deaths
sum_yearly_deaths_by_sex = sum_yearly_deaths_by_sex.sort_values(by='Deaths: All Ages')

# Plot the data
plt.figure(figsize=(10, 6))

# Define the width of each bar
bar_width = 0.35

# Get the unique years and sexes
years = sum_yearly_deaths_by_sex['Year'].unique()
sexes = sum_yearly_deaths_by_sex['Sex'].unique()

# Create an array of positions for the bars
r = np.arange(len(years))

# Plot each sex's data
for i, sex in enumerate(sexes):
    subset = sum_yearly_deaths_by_sex[sum_yearly_deaths_by_sex['Sex'] == sex]
    bars = plt.bar(r + i * bar_width, subset['Deaths: All Ages'], width=bar_width, label=sex)

    # Add text annotations
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{int(yval):,}', ha='center', va='bottom')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Deaths: All Ages')
plt.title('Total Deaths by Year and Sex')
plt.xticks(r + bar_width / 2, years)
plt.legend(title='Sex')
plt.show()

# %% [markdown]
# ### Get and Plot Total Deaths for All Countries with Population Data

# %%
pd.options.display.float_format = '{:,.0f}'.format

# Group the Population dataframe by 'Pop: All Ages' column
df_pop_filtered = df_pop[df_pop['Year'].between(2017, 2021)]
df_pop_filtered = df_pop_filtered.groupby(['Year', 'Country Name'])['Pop: All Ages'].sum().reset_index()

# Rename the column to 'Total Population'
df_pop_filtered = df_pop_filtered.rename(columns={'Pop: All Ages': 'Total Population'})

# Display the first few rows
display(df_pop_filtered)
# Out:
#     Year Country Name  Total Population
# 0   2017    Australia        24,594,202
# 1   2017      Iceland           343,400
# 2   2017       Israel         8,713,268
# 3   2017        Japan       124,648,471
# 4   2017       Poland        37,962,318
# 5   2017    Singapore         3,965,796
# 6   2017       Sweden        10,057,698
# 7   2018    Australia        24,963,258
# 8   2018      Iceland           352,720
# 9   2018       Israel         8,882,765
# 10  2018        Japan       124,218,285
# 11  2018       Poland        37,948,140
# 12  2018    Singapore         3,994,283
# 13  2018       Sweden        10,175,214
# 14  2019    Australia        25,334,826
# 15  2019       Brazil       210,147,125
# 16  2019      Iceland           360,563
# 17  2019       Israel         9,054,034
# 18  2019        Japan       123,731,176
# 19  2019       Poland        37,948,140
# 20  2019    Singapore         4,026,209
# 21  2019       Sweden        10,278,887
# 22  2020    Australia        25,649,248
# 23  2020      Iceland           366,463
# 24  2020       Israel         9,215,117
# 25  2020        Japan       123,398,962
# 26  2020       Poland        37,929,735
# 27  2020    Singapore         4,044,210
# 28  2020       Sweden        10,353,442
# 29  2021    Australia        25,685,412
# 30  2021      Iceland           372,520
# 31  2021       Israel         9,371,368
# 32  2021        Japan       122,780,487
# 33  2021       Poland        37,737,212
# 34  2021    Singapore         3,986,842
# 35  2021       Sweden        10,415,810

# %%
# Create a DataFrame of deaths per year

# Filter to the 'AAA' ICD Code since that applies to the total deaths for all ICD Codes
df_filtered_grouped_deaths = df_mort[df_mort['ICD Code'] == 'AAA']

# Group by Year + Country and Deaths
df_grouped_deaths = df_filtered_grouped_deaths.groupby(['Year', 'Country Name'])['Deaths: All Ages'].sum().reset_index()

# Rename columns
df_grouped_deaths = df_grouped_deaths.rename(columns={'Deaths: All Ages':'All Causes of Death'})

# Convert the 'All Deaths' column to integer
df_grouped_deaths['All Causes of Death'] = df_grouped_deaths['All Causes of Death'].fillna(0).astype(int)

# Apply comma formatting
# df_grouped_deaths['All Causes of Death'] = df_grouped_deaths['All Causes of Death'].map(lambda x: f"{x:,}")

# Display first few rows
display(df_grouped_deaths.head())
# Out:
#    Year Country Name  All Causes of Death
# 0  2017    Australia               161083
# 1  2017       Brazil              1312664
# 2  2017       Canada               276689
# 3  2017        Chile               106388
# 4  2017      Iceland                 2236

# %% [markdown]
# # Create Scatterplots

# %%
# Group by Year + Country and Deaths
df_filtered_grouped_deaths = df_mort[df_mort['ICD Code'] != 'AAA']
df_grouped_deaths = df_filtered_grouped_deaths.groupby(['Year', 'Country Name'])['Deaths: All Ages'].sum().reset_index()

# Rename columns
df_grouped_deaths = df_grouped_deaths.rename(columns={'Deaths: All Ages':'All Causes of Death'})

# Convert the 'All Deaths' column to integer
df_grouped_deaths['All Causes of Death'] = df_grouped_deaths['All Causes of Death'].fillna(0).astype(int)

# Merge the two DataFrames on 'Year' and 'Country Name'
df_merged = pd.merge(df_pop_filtered, df_grouped_deaths, on=['Year', 'Country Name'])

# Calculate the percentage of the population that died in each year
df_merged['Percentage'] = (df_merged['All Causes of Death'] / df_merged['Total Population']) * 100

# Format the percentage column to show two decimal places
df_merged['Percentage'] = df_merged['Percentage'].map(lambda x: f"{x:.2f}")

# Display the merged DataFrame
display(df_merged.head())
# Out:
#    Year Country Name  Total Population  All Causes of Death Percentage
# 0  2017    Australia        24,594,202               161083       0.65
# 1  2017      Iceland           343,400                 2236       0.65
# 2  2017       Israel         8,713,268                44596       0.51
# 3  2017        Japan       124,648,471              1340397       1.08
# 4  2017       Poland        37,962,318               402852       1.06

# %%
# Create a DataFrame to exclude 'AAA' so that we don't double-count. AAA represents deaths from all ICD codes.
df_mort_filtered_no_aaa = df_mort[df_mort['ICD Code'] != 'AAA']

# Create a DataFrame to only include 'AAA' to a summary rollup
df_mort_aaa = df_mort[df_mort['ICD Code'] == 'AAA']

# Show the first few rows for both DataFrames
display(df_mort_filtered_no_aaa.head(2))
display(df_mort_aaa.head(2))
# Out:
#    Year  Country Code Country Name           Region       Sex ICD Code  \
# 0  2017          4160      Iceland  Northern Europe  1 - Male      A02
# 1  2017          4160      Iceland  Northern Europe  1 - Male      A04
#
#                         ICD Category  ICD10 Version  Deaths: All Ages  \
# 0  Infectious and parasitic diseases            103                 1
# 1  Infectious and parasitic diseases            103                 1
#
#    Deaths: 0-1 Years  Deaths: 1-24 Years  Deaths: 25-44 Years  \
# 0                  0                   0                    0
# 1                  0                   0                    0
#
#    Deaths: 45-69 Years  Deaths: 70-95+ Years  Deaths: Age Not Specified  \
# 0                    0                     1                          0
# 1                    0                     1                          0
#
#    Age Format  Deaths: Smoketest All Ages
# 0           0                           1
# 1           0                           1
#      Year  Country Code Country Name           Region         Sex ICD Code  \
# 5    2017          4160      Iceland  Northern Europe    1 - Male      AAA
# 185  2017          4160      Iceland  Northern Europe  2 - Female      AAA
#
#                           ICD Category  ICD10 Version  Deaths: All Ages  \
# 5    Infectious and parasitic diseases            103              1124
# 185  Infectious and parasitic diseases            103              1112
#
#      Deaths: 0-1 Years  Deaths: 1-24 Years  Deaths: 25-44 Years  \
# 5                    5                  24                   47
# 185                  5                  11                   17
#
#      Deaths: 45-69 Years  Deaths: 70-95+ Years  Deaths: Age Not Specified  \
# 5                    320                   507                          0
# 185                  203                   626                          0
#
#      Age Format  Deaths: Smoketest All Ages
# 5             0                       1,124
# 185           0                       1,112

# %%
df_mort_filtered_no_aaa.columns
# Out:
# Index(['Year', 'Country Code', 'Country Name', 'Region', 'Sex', 'ICD Code',
#        'ICD Category', 'ICD10 Version', 'Deaths: All Ages',
#        'Deaths: 0-1 Years', 'Deaths: 1-24 Years', 'Deaths: 25-44 Years',
#        'Deaths: 45-69 Years', 'Deaths: 70-95+ Years',
#        'Deaths: Age Not Specified', 'Age Format',
#        'Deaths: Smoketest All Ages'],
#       dtype='object')

# %%
# Create a pivot table to summarize total deaths by ICD code for each country and year
pivot_table_all_years = pd.pivot_table(
    df_mort_filtered_no_aaa, 
    values='Deaths: All Ages', 
    index=['Country Name', 'Year'], 
    columns=['ICD Code'], 
    aggfunc='sum'
)

# Reset the index to make 'Country Name' and 'Year' columns
pivot_table_reset = pivot_table_all_years.reset_index()

# Melt the pivot table to long format
melted = pivot_table_reset.melt(id_vars=['Country Name', 'Year'], var_name='ICD Code', value_name='Deaths')

# Rank the ICD codes within each country and year based on the number of deaths
melted['Rank'] = melted.groupby(['Country Name', 'Year'])['Deaths'].rank(method='first', ascending=False)

# Filter to include only the top 5 ICD codes for each country and year
top_5_all_years = melted[melted['Rank'] <= 5]

# Sort by country, year, and rank
top_5_all_years_sorted = top_5_all_years.sort_values(by=['Country Name', 'Year', 'Rank'])

# Display the sorted DataFrame
display(top_5_all_years_sorted)
# Out:
#                     Country Name  Year ICD Code  Deaths  Rank
# 46226                  Australia  2017     C349   8,141     1
# 110838                 Australia  2017      F03   8,078     2
# 153410                 Australia  2017     I219   7,530     3
# 154396                 Australia  2017     I259   6,786     4
# 163560                 Australia  2017      I64   4,297     5
# ...                          ...   ...      ...     ...   ...
# 329149  United States of America  2021     U071 416,893     1
# 154105  United States of America  2021     I251 162,314     2
# 46283   United States of America  2021     C349 130,222     3
# 132239  United States of America  2021     G309 112,004     4
# 178059  United States of America  2021     J449 108,245     5
#
# [290 rows x 5 columns]

# %%
# Merge the population data with the deaths data
df_merged_pop_deaths = pd.merge(df_pop_filtered, top_5_all_years_sorted, on=['Year', 'Country Name'])

# Filter out Brazil
df_merged_pop_deaths = df_merged_pop_deaths[df_merged_pop_deaths['Country Name'] != 'Brazil']

# Convert 'Total Population' to millions using .loc to avoid SettingWithCopyWarning
df_merged_pop_deaths.loc[:, 'Total Population'] = df_merged_pop_deaths['Total Population'] / 1_000_000

# Create the bubble plot
plt.figure(figsize=(14, 8))
bubble_plot = sns.scatterplot(
    data=df_merged_pop_deaths, 
    x='Total Population', 
    y='Deaths', 
    hue='ICD Code', 
    style='Country Name', 
    size='Total Population', 
    sizes=(20, 200), 
    palette='viridis'
)

# Set the x-axis formatter to ScalarFormatter and disable scientific notation
bubble_plot.xaxis.set_major_formatter(ScalarFormatter())
bubble_plot.ticklabel_format(style='plain', axis='x')

# Customize the plot
bubble_plot.set_title('Number of Deaths vs Population Size for Top 5 ICD Codes')
bubble_plot.set_xlabel('Population Size (Millions)')
bubble_plot.set_ylabel('Number of Deaths')
plt.legend(bbox_to_anchor=(0.5, -0.1), loc='upper center', ncol=3)


# Add data labels for COVID-19 ICD codes
for line in range(0, df_merged_pop_deaths.shape[0]):
    if df_merged_pop_deaths['ICD Code'].iloc[line] == 'COVID-19':
        plt.text(
            df_merged_pop_deaths['Total Population'].iloc[line],
            df_merged_pop_deaths['Deaths'].iloc[line],
            'COVID',
            horizontalalignment='left',
            size='medium',
            color='black',
            weight='semibold'
        )
        
# Show the plot
plt.show()

# %%
# Reuse existing merged 
total_deaths_covid = df_merged_pop_deaths

# Filter the DataFrame to get COVID-19 specific codes
covid_codes = ['U071', 'U072']  # Example COVID-19 ICD codes
covid_deaths = df_merged_pop_deaths[df_merged_pop_deaths['ICD Code'].isin(covid_codes)].groupby(['Year', 'Country Name', 'Total Population'])['Deaths'].sum().reset_index()
covid_deaths['ICD Code'] = 'COVID-19'

# Combine the total deaths and COVID-19 deaths
comparison_df = pd.concat([total_deaths_covid, covid_deaths])

# Ensure 'Total Population' and 'Deaths' are numeric
comparison_df['Total Population'] = pd.to_numeric(comparison_df['Total Population'], errors='coerce')
comparison_df['Deaths'] = pd.to_numeric(comparison_df['Deaths'], errors='coerce')

# Drop rows with NaN values in 'Total Population' or 'Deaths'
comparison_df.dropna(subset=['Total Population', 'Deaths'], inplace=True)

# Filter out Brazil
comparison_df = comparison_df[comparison_df['Country Name'] != 'Brazil']

# Create the bubble plot
plt.figure(figsize=(14, 8))
bubble_plot = sns.scatterplot(
    data=comparison_df, 
    x='Total Population', 
    y='Deaths', 
    hue='ICD Code', 
    style='Country Name', 
    size='Total Population', 
    sizes=(40, 400), 
    palette='viridis'
)

# Set the x-axis formatter to ScalarFormatter and disable scientific notation
bubble_plot.xaxis.set_major_formatter(ScalarFormatter())
bubble_plot.ticklabel_format(style='plain', axis='x')

# Customize the plot
bubble_plot.set_title('Number of Deaths vs Population Size for COVID-19 and All Deaths')
bubble_plot.set_xlabel('Population Size (Millions)')
bubble_plot.set_ylabel('Number of Deaths')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Add data labels for COVID-19 ICD codes
for line in range(0, comparison_df.shape[0]):
    if comparison_df['ICD Code'].iloc[line] == 'COVID-19':
        plt.text(
            comparison_df['Total Population'].iloc[line],
            comparison_df['Deaths'].iloc[line],
            'COVID',
            horizontalalignment='left',
            size='medium',
            color='black',
            weight='semibold'
        )

# Show the plot
plt.show()

# %%
# Filter the DataFrame to only include the years 2017-2019
df_filtered_2020_2021 = df_merged[df_merged['Year'].between(2020, 2021)]


# Check if the required columns exist in the DataFrame
required_columns = ['Year', 'Country Name', 'Total Population', 'All Causes of Death', 'Percentage']
for col in required_columns:
    if col not in df_merged.columns:
        raise ValueError(f"Column '{col}' not found in DataFrame")


df_filter_brazil = df_merged[df_merged['Country Name'] != 'Brazil']

# Group by 'Country Name' and aggregate the relevant columns
df_aggregated_all_years = df_filter_brazil.groupby('Country Name').agg({
    'Total Population': lambda x: x.astype(float).mean(),
    'All Causes of Death': lambda x: x.astype(int).sum(),
    'Percentage': lambda x: x.astype(float).mean()
}).reset_index()

# Print the aggregated DataFrame to check the processed data
print("Aggregated DataFrame:")
print(df_aggregated_all_years.head())

# Extract the relevant columns from the aggregated DataFrame
countries = df_aggregated_all_years['Country Name']
total_population = df_aggregated_all_years['Total Population'] / 1_000_000  # Convert to millions
all_causes_of_death = df_aggregated_all_years['All Causes of Death']
percentage = df_aggregated_all_years['Percentage']

# Scale the percentage for bubble size
bubble_size = percentage * 100 * 2  # Adjust the scaling factor as needed

# Create the scatterplot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(total_population, all_causes_of_death, s=bubble_size, c=percentage, cmap='viridis', alpha=0.6, edgecolors='w', linewidth=0.5)

# Set the x-axis formatter to ScalarFormatter and disable scientific notation
formatter = ScalarFormatter(useOffset=False, useMathText=False)
formatter.set_scientific(False)
plt.gca().xaxis.set_major_formatter(ScalarFormatter())
plt.gca().ticklabel_format(style='plain', axis='x')

# Add color bar
cbar = plt.colorbar(scatter)
cbar.set_label('Percentage of Population Died')

# Add titles and labels
plt.title('Scatterplot of Total Population vs. All Causes of Death')
plt.xlabel('Total Population (Millions)')
plt.ylabel('All Causes of Death')

# Annotate each point with the country name
for i, country in enumerate(countries):
    plt.annotate(country, (total_population[i], all_causes_of_death[i]), fontsize=8, alpha=0.7)

# Show the plot
plt.show()
# Out:
# Aggregated DataFrame:
#   Country Name  Total Population  All Causes of Death  Percentage
# 0    Australia        25,245,389               821474           1
# 1      Iceland           359,133                11409           1
# 2       Israel         9,047,310               234706           1
# 3        Japan       123,755,476              6896571           1
# 4       Poland        37,905,109              2223633           1

# %%
def calculate_and_print_correlation(df, col1, col2):
    """
    Calculate and print the correlation between two columns in a DataFrame.
    
    Parameters:
    df (pd.DataFrame): The DataFrame containing the data.
    col1 (str): The name of the first column.
    col2 (str): The name of the second column.
    """
    correlation = df[col1].corr(df[col2])
    if correlation >= 0.7:
        print("The correlation is very strong")
    elif 0.5 <= correlation < 0.7:
        print("The correlation is strong")
    elif 0.3 <= correlation < 0.5:
        print("There's moderate correlation")
    elif 0.1 <= correlation < 0.3:
        print("There's weak correlation")
    else:
        print("There's no correlation")
    print(f"Correlation between '{col1}' and '{col2}': {correlation}")

# %%
# Calculate correlation for All Years
calculate_and_print_correlation(df_aggregated_all_years, 'All Causes of Death', 'Total Population')
# Out:
# The correlation is very strong
# Correlation between 'All Causes of Death' and 'Total Population': 0.9959700978691334

# %%
# Filter the DataFrame to only include the years 2020-2021
df_filtered_2020_2021 = df_merged[df_merged['Year'].between(2020, 2021)]

# Check if the required columns exist in the filtered DataFrame
required_columns = ['Year', 'Country Name', 'Total Population', 'All Causes of Death', 'Percentage']
for col in required_columns:
    if col not in df_filtered_2020_2021.columns:
        raise ValueError(f"Column '{col}' not found in DataFrame")

# Print the filtered DataFrame to check the raw data
print("Filtered DataFrame:")
print(df_filtered_2020_2021.head())

# Group by 'Country Name' and aggregate the relevant columns
df_aggregated_2020_2021 = df_filtered_2020_2021.groupby('Country Name').agg({
    'Total Population': lambda x: x.astype(float).mean(),
    'All Causes of Death': lambda x: x.astype(int).sum(),
    'Percentage': lambda x: x.astype(float).mean()
}).reset_index()

# Print the aggregated DataFrame to check the processed data
print("Aggregated DataFrame:")
print(df_aggregated_2020_2021.head())

# Extract the relevant columns from the aggregated DataFrame
countries = df_aggregated_2020_2021['Country Name']
total_population = df_aggregated_2020_2021['Total Population'] / 1_000_000  # Convert to millions
all_causes_of_death = df_aggregated_2020_2021['All Causes of Death']
percentage = df_aggregated_2020_2021['Percentage']

# Scale the percentage for bubble size and multiply by 2
bubble_size = percentage * 100 * 2

# Create the scatterplot
plt.figure(figsize=(10, 6))
scatter = plt.scatter(total_population, all_causes_of_death, s=bubble_size, c=percentage, cmap='magma', alpha=0.6, edgecolors='w', linewidth=0.5)

# Add color bar
cbar = plt.colorbar(scatter)
cbar.set_label('Percentage of Population Died')

# Set the x-axis formatter to ScalarFormatter and disable scientific notation
plt.gca().xaxis.set_major_formatter(ScalarFormatter())
plt.gca().ticklabel_format(style='plain', axis='x')

# Add titles and labels
plt.title('Scatterplot of Total Population vs. All Causes of Death (2020-2021)')
plt.xlabel('Total Population (Millions)')
plt.ylabel('All Causes of Death')

# Annotate each point with the country name at the bottom right of the bubble
for i, country in enumerate(countries):
    plt.annotate(country, 
                 (total_population[i], all_causes_of_death[i]), 
                 xytext=(5, -5),  # Offset position
                 textcoords='offset points', 
                 fontsize=7, 
                 alpha=0.8,
                 ha='left',  # Horizontal alignment
                 va='top')   # Vertical alignment

# Show the plot
plt.show()
# Out:
# Filtered DataFrame:
#     Year Country Name  Total Population  All Causes of Death Percentage
# 22  2020    Australia        25,649,248               161300       0.63
# 23  2020      Iceland           366,463                 2305       0.63
# 24  2020       Israel         9,215,117                48797       0.53
# 25  2020        Japan       123,398,962              1372755       1.11
# 26  2020       Poland        37,929,735               477355       1.26
# Aggregated DataFrame:
#   Country Name  Total Population  All Causes of Death  Percentage
# 0    Australia        25,667,330               332769           1
# 1      Iceland           369,492                 4638           1
# 2       Israel         9,293,243                99569           1
# 3        Japan       123,089,724              2812611           1
# 4       Poland        37,833,474               996872           1

# %%
# Calculate correlation for 2020-2021
calculate_and_print_correlation(df_aggregated_2020_2021, 'All Causes of Death', 'Total Population')
# Out:
# The correlation is very strong
# Correlation between 'All Causes of Death' and 'Total Population': 0.9935867838459576
